# %% [markdown]
# # 1) Análise exploratória de dados
# ## 1.1) Arquivo train.csv

# %%
import pandas as pd

# %% [markdown]
# ### O arquivo train.csv relaciona IDs com nomes de estudos e com labels indicando qual dataset cada estudo menciona.
# ### Os IDs correspondem a arquivos JSON dentro do diretório /train, cada um contento o texto de um estudo.

# %%
dataset = pd.read_csv('train.csv')

# %%
dataset
# Out:
#                                          Id  \
# 0      d0fa7568-7d8e-4db9-870f-f9c6f668c17b
# 1      2f26f645-3dec-485d-b68d-f013c9e05e60
# 2      c5d5cd2c-59de-4f29-bbb1-6a88c7b52f29
# 3      5c9a3bc9-41ba-4574-ad71-e25c1442c8af
# 4      c754dec7-c5a3-4337-9892-c02158475064
# ...                                     ...
# 19656  b3498176-8832-4033-aea6-b5ea85ea04c4
# 19657  f77eb51f-c3ac-420b-9586-cb187849c321
# 19658  ab59bcdd-7b7c-4107-93f5-0ccaf749236c
# 19659  fd23e7e0-a5d2-4f98-992d-9209c85153bb
# 19660  fd23e7e0-a5d2-4f98-992d-9209c85153bb
#
#                                                pub_title  \
# 0      The Impact of Dual Enrollment on College Degre...
# 1      Educational Attainment of High School Dropouts...
# 2      Differences in Outcomes for Female and Male St...
# 3      Stepping Stone and Option Value in a Model of ...
# 4      Parental Effort, School Resources, and Student...
# ...                                                  ...
# 19656  RSNA International Trends: A Global Perspectiv...
# 19657  MCCS: a novel recognition pattern-based method...
# 19658  Quantitative Structure–Activity Relationship M...
# 19659  A ligand-based computational drug repurposing ...
# 19660  A ligand-based computational drug repurposing ...
#
#                                            dataset_title  \
# 0                  National Education Longitudinal Study
# 1                  National Education Longitudinal Study
# 2                  National Education Longitudinal Study
# 3                  National Education Longitudinal Study
# 4                  National Education Longitudinal Study
# ...                                                  ...
# 19656  RSNA International COVID-19 Open Radiology Dat...
# 19657  CAS COVID-19 antiviral candidate compounds dat...
# 19658  CAS COVID-19 antiviral candidate compounds dat...
# 19659  CAS COVID-19 antiviral candidate compounds dat...
# 19660  CAS COVID-19 antiviral candidate compounds dat...
#
#                                            dataset_label  \
# 0                  National Education Longitudinal Study
# 1                  National Education Longitudinal Study
# 2                  National Education Longitudinal Study
# 3                  National Education Longitudinal Study
# 4                  National Education Longitudinal Study
# ...                                                  ...
# 19656   RSNA International COVID Open Radiology Database
# 19657  CAS COVID-19 antiviral candidate compounds dat...
# 19658  CAS COVID-19 antiviral candidate compounds dat...
# 19659  CAS COVID-19 antiviral candidate compounds dat...
# 19660    CAS COVID-19 antiviral candidate compounds data
#
#                                            cleaned_label
# 0                  national education longitudinal study
# 1                  national education longitudinal study
# 2                  national education longitudinal study
# 3                  national education longitudinal study
# 4                  national education longitudinal study
# ...                                                  ...
# 19656   rsna international covid open radiology database
# 19657  cas covid 19 antiviral candidate compounds dat...
# 19658  cas covid 19 antiviral candidate compounds dat...
# 19659  cas covid 19 antiviral candidate compounds dat...
# 19660    cas covid 19 antiviral candidate compounds data
#
# [19661 rows x 5 columns]

# %% [markdown]
# ### São quase 20 mil linhas, mas o código abaixo mostra que há apenas cerca de 14 mil estudos únicos. (Curiosamente, o número de IDs e de títulos distintos não bate...!) São então cerca de 5 mil estudos repetidos, possivelmente envolvendo linhas com exatamente as mesmas informações.

# %%
print(len(dataset["Id"].unique()))
print(len(dataset["pub_title"].unique()))
# Out:
# 14316
# 14268

# %% [markdown]
# ### Ao todo, 156 diferentes datasets são citados em todos esses estudos. O número provavelmente é menor, porque parece que os mesmos datasets às vezes são referidos com nomes diferentes. Por exemplo, aqueles perto do final mencionando o genôma do SARS-CoV-19.

# %%
x = dataset['cleaned_label'].unique()
print(len(x))
x
# Out:
# 156
# array(['national education longitudinal study', 'noaa tidal station',
#        'slosh model', 'noaa c cap', 'aging integrated database agid ',
#        'alzheimers disease neuroimaging initiative',
#        'aging integrated database',
#        'noaa national water level observation network',
#        'noaa water level station',
#        'baltimore longitudinal study of aging blsa ',
#        'Baltimore Longitudinal Study of Aging (BLSA)',
#        'national water level observation network',
#        'arms farm financial and crop production practices',
#        'beginning postsecondary student',
#        'noaa sea lake and overland surges from hurricanes',
#        'noaa tide gauge',
#        'the national institute on aging genetics of alzheimer s disease data storage site',
#        'national center for education statistics common core of data',
#        'national science foundation survey of industrial research and development',
#        'baccalaureate and beyond',
#        'noaa international best track archive for climate stewardship',
#        'agricultural resource management survey',
#        'national teacher and principal survey',
#        'international best track archive for climate stewardship',
#        'nsf higher education research and development survey',
#        'national science foundation survey of earned doctorates',
#        'school survey on crime and safety',
#        'the national institute on aging genetics of alzheimer s disease data storage site niagads ',
#        'national oceanic and atmospheric administration world ocean database',
#        'beginning postsecondary students longitudinal study',
#        'nces common core of data',
#        'program for the international assessment of adult competencies',
#        'survey of earned doctorates',
#        'baltimore longitudinal study of aging',
#        'Baltimore Longitudinal Study of Aging',
#        'early childhood longitudinal study', 'adni', 'ADNI',
#        "Alzheimer's Disease Neuroimaging Initiative (ADNI)",
#        'national science foundation survey of graduate students and postdoctorates in science and engineering',
#        'trends in international mathematics and science study',
#        'Trends in International Mathematics and Science Study',
#        'national oceanic and atmospheric administration c cap',
#        'nsf survey of earned doctorates', 'noaa tide station',
#        'education longitudinal study',
#        'optimum interpolation sea surface temperature',
#        'national oceanic and atmospheric administration optimum interpolation sea surface temperature',
#        'alzheimer s disease neuroimaging initiative adni ',
#        'baccalaureate and beyond longitudinal study',
#        'agricultural resources management survey',
#        'beginning postsecondary students', 'ibtracs',
#        'coastal change analysis program',
#        'survey of graduate students and postdoctorates in science and engineering',
#        'national assessment of education progress',
#        'sea surface temperature optimum interpolation',
#        'high school longitudinal study',
#        'nsf survey of graduate students and postdoctorates in science and engineering',
#        'national science foundation survey of doctorate recipients',
#        'survey of doctorate recipients',
#        'coastal change analysis program land cover',
#        'survey of industrial research and development',
#        'world ocean database', 'rural urban continuum codes',
#        'noaa optimum interpolation sea surface temperature',
#        'noaa world ocean database', 'common core of data',
#        'higher education research and development survey',
#        'Beginning Postsecondary Students Longitudinal Study',
#        'Beginning Postsecondary Student',
#        'Beginning Postsecondary Students', 'Baccalaureate and Beyond',
#        'Baccalaureate and Beyond Longitudinal Study',
#        'Education Longitudinal Study',
#        'National Education Longitudinal Study',
#        'Survey of Earned Doctorates',
#        'Early Childhood Longitudinal Study',
#        'National Assessment of Education Progress',
#        'National Teacher and Principal Survey',
#        'School Survey on Crime and Safety',
#        'High School Longitudinal Study',
#        'Program for the International Assessment of Adult Competencies',
#        'noaa storm surge inundation',
#        'national weather service nws storm surge risk',
#        'survey of science and engineering research facilities',
#        'nsf survey of industrial research and development',
#        'national science foundation survey of science and engineering research facilities',
#        'national science foundation higher education research and development survey',
#        'national center for science and engineering statistics survey of earned doctorates',
#        'national center for science and engineering statistics survey of science and engineering research facilities',
#        'national center for science and engineering statistics survey of graduate students and postdoctorates in science and engineering',
#        'national center for science and engineering statistics survey of doctorate recipients',
#        'national center for science and engineering statistics survey of industrial research and development',
#        'national center for science and engineering statistics higher education research and development survey',
#        'nsf survey of science and engineering research facilities',
#        'ffrdc research and development survey',
#        'nsf ffrdc research and development survey',
#        'survey of state government research and development',
#        'ncses survey of doctorate recipients',
#        'Survey of Graduate Students and Postdoctorates in Science and Engineering',
#        'ncses survey of graduate students and postdoctorates in science and engineering',
#        'Survey of Industrial Research and Development',
#        'NOAA tidal station', 'Agricultural Resource Management Survey',
#        'anss comprehensive earthquake catalog',
#        'anss comprehensive catalog',
#        'advanced national seismic system anss comprehensive catalog comcat ',
#        'advanced national seismic system comprehensive catalog',
#        'census of agriculture', 'usda census of agriculture',
#        'nass census of agriculture',
#        'north american breeding bird survey',
#        'north american breeding bird survey bbs ',
#        'usgs north american breeding bird survey',
#        'covid 19 open research dataset cord 19 ',
#        'covid 19 open research dataset', 'covid open research dataset',
#        'covid 19 open research data',
#        'complexity science hub covid 19 control strategies list cccsl ',
#        'complexity science hub covid 19 control strategies list', 'cccsl',
#        'our world in data covid 19 dataset', 'our world in data covid 19',
#        'our world in data', 'Our World in Data', 'jh crown registry',
#        'characterizing health associated risks and your baseline disease in sars cov 2 charybdis ',
#        'characterizing health associated risks and your baseline disease in sars cov 2',
#        'covid 19 death data', 'sars cov 2 genome sequence',
#        'SARS-CoV-2 genome sequence', 'sars cov 2 genome sequences',
#        'SARS-CoV-2 genome sequences', 'covid 19 genome sequence',
#        'covid 19 genome sequences', '2019 ncov genome sequence',
#        '2019 ncov genome sequences', 'sars cov 2 full genome sequence',
#        'sars cov 2 full genome sequences',
#        'sars cov 2 complete genome sequence',
#        'sars cov 2 complete genome sequences',
#        '2019 ncov complete genome sequences',
#        'genome sequences of sars cov 2', 'genome sequence of sars cov 2',
#        'genome sequence of covid 19', 'genome sequences of covid 19',
#        'genome sequence of 2019 ncov', 'genome sequences of 2019 ncov',
#        'covid 19 image data collection',
#        'rsna international covid 19 open radiology database ricord ',
#        'rsna international covid 19 open radiology database',
#        'rsna international covid open radiology database',
#        'cas covid 19 antiviral candidate compounds dataset',
#        'cas covid 19 antiviral candidate compounds data set',
#        'cas covid 19 antiviral candidate compounds data'], dtype=object)

# %% [markdown]
# ### Não há informações faltantes. Antes, eu achava que nossa missão era detectar SE um estudo cita um dataset, mas agora vejo que cada estudo cita exatamente um dataset e precisamos saber QUAL. Creio que as citações ocorrerão apenas dentre os 156 datasets acima... ou é algo aberto a qualquer dataset possível do mundo?

# %%
print(dataset['Id'].isna().sum())
print(dataset['pub_title'].isna().sum())
print(dataset['cleaned_label'].isna().sum())
# Out:
# 0
# 0
# 0

# %% [markdown]
# ### Os estudos variam muito em sua frequência de citação. Muitos são citados centenas de vezes, outros são citados apenas algumas vezes (sem levar em conta duplicatas).

# %%
for label, count in dataset['cleaned_label'].value_counts().items():
    print(f"{count} times: {label}.")
# Out:
# 3660 times: adni.
# 2390 times: alzheimer s disease neuroimaging initiative adni .
# 1152 times: baltimore longitudinal study of aging.
# 1151 times: trends in international mathematics and science study.
# 1003 times: early childhood longitudinal study.
# 671 times: education longitudinal study.
# 643 times: census of agriculture.
# 621 times: agricultural resource management survey.
# 545 times: national education longitudinal study.
# 490 times: rural urban continuum codes.
# 431 times: baltimore longitudinal study of aging blsa .
# 426 times: survey of earned doctorates.
# 380 times: north american breeding bird survey.
# 314 times: world ocean database.
# 304 times: slosh model.
# 299 times: noaa tide gauge.
# 298 times: survey of doctorate recipients.
# 280 times: ibtracs.
# 255 times: coastal change analysis program.
# 252 times: common core of data.
# 242 times: sars cov 2 genome sequences.
# 239 times: beginning postsecondary students.
# 222 times: genome sequence of sars cov 2.
# 210 times: our world in data.
# 198 times: north american breeding bird survey bbs .
# 191 times: baccalaureate and beyond.
# 190 times: optimum interpolation sea surface temperature.
# 158 times: genome sequences of sars cov 2.
# 148 times: beginning postsecondary students longitudinal study.
# 133 times: sars cov 2 genome sequence.
# 128 times: national assessment of education progress.
# 114 times: covid 19 open research dataset.
# 105 times: international best track archive for climate stewardship.
# 100 times: baccalaureate and beyond longitudinal study.
# 87 times: usda census of agriculture.
# 87 times: survey of industrial research and development.
# 86 times: noaa optimum interpolation sea surface temperature.
# 86 times: high school longitudinal study.
# 71 times: alzheimers disease neuroimaging initiative.
# 69 times: survey of graduate students and postdoctorates in science and engineering.
# 67 times: beginning postsecondary student.
# 65 times: covid 19 open research dataset cord 19 .
# 64 times: program for the international assessment of adult competencies.
# 64 times: noaa c cap.
# 62 times: national water level observation network.
# 61 times: nces common core of data.
# 58 times: nsf survey of earned doctorates.
# 55 times: national center for education statistics common core of data.
# 43 times: school survey on crime and safety.
# 38 times: covid 19 image data collection.
# 35 times: noaa tide station.
# 28 times: national teacher and principal survey.
# 28 times: covid 19 death data.
# 26 times: higher education research and development survey.
# 24 times: agricultural resources management survey.
# 24 times: noaa tidal station.
# 21 times: national science foundation survey of earned doctorates.
# 19 times: sars cov 2 complete genome sequences.
# 17 times: genome sequence of 2019 ncov.
# 15 times: anss comprehensive catalog.
# 14 times: the national institute on aging genetics of alzheimer s disease data storage site.
# 14 times: noaa national water level observation network.
# 13 times: nass census of agriculture.
# 13 times: arms farm financial and crop production practices.
# 12 times: sars cov 2 full genome sequences.
# 12 times: genome sequences of 2019 ncov.
# 12 times: ADNI.
# 12 times: Trends in International Mathematics and Science Study.
# 11 times: noaa world ocean database.
# 11 times: Alzheimer's Disease Neuroimaging Initiative (ADNI).
# 10 times: nsf survey of graduate students and postdoctorates in science and engineering.
# 10 times: national oceanic and atmospheric administration optimum interpolation sea surface temperature.
# 8 times: Baccalaureate and Beyond.
# 8 times: national science foundation survey of industrial research and development.
# 8 times: Early Childhood Longitudinal Study.
# 8 times: the national institute on aging genetics of alzheimer s disease data storage site niagads .
# 8 times: genome sequences of covid 19.
# 7 times: usgs north american breeding bird survey.
# 7 times: our world in data covid 19.
# 7 times: 2019 ncov genome sequence.
# 7 times: nsf survey of industrial research and development.
# 7 times: anss comprehensive earthquake catalog.
# 7 times: Baccalaureate and Beyond Longitudinal Study.
# 7 times: national science foundation survey of doctorate recipients.
# 7 times: genome sequence of covid 19.
# 7 times: survey of science and engineering research facilities.
# 6 times: coastal change analysis program land cover.
# 6 times: High School Longitudinal Study.
# 6 times: noaa sea lake and overland surges from hurricanes.
# 6 times: noaa water level station.
# 6 times: covid 19 genome sequence.
# 6 times: advanced national seismic system anss comprehensive catalog comcat .
# 5 times: characterizing health associated risks and your baseline disease in sars cov 2 charybdis .
# 5 times: Education Longitudinal Study.
# 5 times: nsf higher education research and development survey.
# 5 times: National Education Longitudinal Study.
# 5 times: covid 19 open research data.
# 5 times: characterizing health associated risks and your baseline disease in sars cov 2.
# 4 times: Baltimore Longitudinal Study of Aging.
# 4 times: covid 19 genome sequences.
# 4 times: 2019 ncov genome sequences.
# 4 times: National Assessment of Education Progress.
# 4 times: our world in data covid 19 dataset.
# 3 times: national center for science and engineering statistics survey of doctorate recipients.
# 3 times: nsf survey of science and engineering research facilities.
# 3 times: Beginning Postsecondary Student.
# 3 times: sars cov 2 full genome sequence.
# 2 times: Agricultural Resource Management Survey.
# 2 times: SARS-CoV-2 genome sequences.
# 2 times: Baltimore Longitudinal Study of Aging (BLSA).
# 2 times: complexity science hub covid 19 control strategies list.
# 2 times: survey of state government research and development.
# 2 times: Survey of Earned Doctorates.
# 2 times: aging integrated database.
# 2 times: national science foundation survey of science and engineering research facilities.
# 2 times: national science foundation higher education research and development survey.
# 2 times: complexity science hub covid 19 control strategies list cccsl .
# 2 times: Our World in Data.
# 2 times: ncses survey of graduate students and postdoctorates in science and engineering.
# 2 times: national center for science and engineering statistics survey of earned doctorates.
# 2 times: ffrdc research and development survey.
# 2 times: cccsl.
# 2 times: cas covid 19 antiviral candidate compounds dataset.
# 2 times: national science foundation survey of graduate students and postdoctorates in science and engineering.
# 2 times: sars cov 2 complete genome sequence.
# 2 times: Beginning Postsecondary Students.
# 2 times: jh crown registry.
# 2 times: Beginning Postsecondary Students Longitudinal Study.
# 2 times: rsna international covid 19 open radiology database.
# 2 times: sea surface temperature optimum interpolation.
# 2 times: National Teacher and Principal Survey.
# 1 times: noaa storm surge inundation.
# 1 times: NOAA tidal station.
# 1 times: cas covid 19 antiviral candidate compounds data set.
# 1 times: national center for science and engineering statistics higher education research and development survey.
# 1 times: national center for science and engineering statistics survey of industrial research and development.
# 1 times: Program for the International Assessment of Adult Competencies.
# 1 times: national oceanic and atmospheric administration world ocean database.
# 1 times: national center for science and engineering statistics survey of graduate students and postdoctorates in science and engineering.
# 1 times: aging integrated database agid .
# 1 times: advanced national seismic system comprehensive catalog.
# 1 times: Survey of Industrial Research and Development.
# 1 times: rsna international covid open radiology database.
# 1 times: noaa international best track archive for climate stewardship.
# 1 times: national center for science and engineering statistics survey of science and engineering research facilities.
# 1 times: national oceanic and atmospheric administration c cap.
# 1 times: Survey of Graduate Students and Postdoctorates in Science and Engineering.
# 1 times: nsf ffrdc research and development survey.
# 1 times: national weather service nws storm surge risk.
# 1 times: School Survey on Crime and Safety.
# 1 times: SARS-CoV-2 genome sequence.
# 1 times: 2019 ncov complete genome sequences.
# 1 times: ncses survey of doctorate recipients.
# 1 times: rsna international covid 19 open radiology database ricord .
# 1 times: covid open research dataset.
# 1 times: cas covid 19 antiviral candidate compounds data.

# %% [markdown]
# ## 1.2) Arquivos em /train
# ### Função que cria um dicionário cujas chaves são IDs e cujos valores são os textos correspondentes, lidos a partir dos arquivos .json no diretório /train

# %%
import os

# %%
def get_JSON(URL):
    dirpath = os.path.join(os.getcwd(), URL)
    id2text = dict()
    for filename in os.listdir(dirpath):
        ID = filename[:-5]
        filepath = os.path.join(dirpath, filename)
        id2text[ID] = open(filepath).read()
    return id2text

# %% [markdown]
# ### Cria um dicionário contendo como entradas os pares ID:texto

# %%
id2text = get_JSON('train')

for ID, text in id2text.items():
    print(ID)
    print(text[:1000])
    break
# Out:
# 0007f880-0a9b-492d-9a58-76eb0b0e0bd7
# [{"section_title": "Abstract", "text": "The aim of this study was to identify if acquiring ICT skills through DOT Lebanon's ICT training program (a local NGO) improved income generation opportunities after 3-months of completing the training. The target population was the NGO's vulnerable young beneficiaries. This study was completed in an effort to find creative and digital solutions to the high rate of youth unemployment in Lebanon (37%), one of the highest rates in the world. Results showed that 48% of beneficiaries who were unemployed at baseline, were exposed to at least one income generation opportunity 3 months after completing the DOT Lebanon training. Also, 49% of beneficiaries who were already employed at baseline were exposed to at least one income generation opportunity. Gender, English proficiency and governorate were variables that were found to be statistically significant. Males were more likely than females to be exposed to income generation opportunities. Those who kn

# %% [markdown]
# # 2) Limpeza de dados
# ### Remove linhas duplicadas com o mesmo ID e torna as linhas acessíveis pelo ID

# %%
dataset.drop_duplicates(subset="Id", inplace=True)
dataset.set_index("Id", inplace=True)
dataset
# Out:
#                                                                               pub_title  \
# Id
# d0fa7568-7d8e-4db9-870f-f9c6f668c17b  The Impact of Dual Enrollment on College Degre...
# 2f26f645-3dec-485d-b68d-f013c9e05e60  Educational Attainment of High School Dropouts...
# c5d5cd2c-59de-4f29-bbb1-6a88c7b52f29  Differences in Outcomes for Female and Male St...
# 5c9a3bc9-41ba-4574-ad71-e25c1442c8af  Stepping Stone and Option Value in a Model of ...
# c754dec7-c5a3-4337-9892-c02158475064  Parental Effort, School Resources, and Student...
# ...                                                                                 ...
# f89dd9fa-07af-4384-aa0c-0d14602c0cea  Artificial Intelligence of COVID-19 Imaging: A...
# b3498176-8832-4033-aea6-b5ea85ea04c4  RSNA International Trends: A Global Perspectiv...
# f77eb51f-c3ac-420b-9586-cb187849c321  MCCS: a novel recognition pattern-based method...
# ab59bcdd-7b7c-4107-93f5-0ccaf749236c  Quantitative Structure–Activity Relationship M...
# fd23e7e0-a5d2-4f98-992d-9209c85153bb  A ligand-based computational drug repurposing ...
#
#                                                                           dataset_title  \
# Id
# d0fa7568-7d8e-4db9-870f-f9c6f668c17b              National Education Longitudinal Study
# 2f26f645-3dec-485d-b68d-f013c9e05e60              National Education Longitudinal Study
# c5d5cd2c-59de-4f29-bbb1-6a88c7b52f29              National Education Longitudinal Study
# 5c9a3bc9-41ba-4574-ad71-e25c1442c8af              National Education Longitudinal Study
# c754dec7-c5a3-4337-9892-c02158475064              National Education Longitudinal Study
# ...                                                                                 ...
# f89dd9fa-07af-4384-aa0c-0d14602c0cea  RSNA International COVID-19 Open Radiology Dat...
# b3498176-8832-4033-aea6-b5ea85ea04c4  RSNA International COVID-19 Open Radiology Dat...
# f77eb51f-c3ac-420b-9586-cb187849c321  CAS COVID-19 antiviral candidate compounds dat...
# ab59bcdd-7b7c-4107-93f5-0ccaf749236c  CAS COVID-19 antiviral candidate compounds dat...
# fd23e7e0-a5d2-4f98-992d-9209c85153bb  CAS COVID-19 antiviral candidate compounds dat...
#
#                                                                           dataset_label  \
# Id
# d0fa7568-7d8e-4db9-870f-f9c6f668c17b              National Education Longitudinal Study
# 2f26f645-3dec-485d-b68d-f013c9e05e60              National Education Longitudinal Study
# c5d5cd2c-59de-4f29-bbb1-6a88c7b52f29              National Education Longitudinal Study
# 5c9a3bc9-41ba-4574-ad71-e25c1442c8af              National Education Longitudinal Study
# c754dec7-c5a3-4337-9892-c02158475064              National Education Longitudinal Study
# ...                                                                                 ...
# f89dd9fa-07af-4384-aa0c-0d14602c0cea  RSNA International COVID-19 Open Radiology Dat...
# b3498176-8832-4033-aea6-b5ea85ea04c4   RSNA International COVID Open Radiology Database
# f77eb51f-c3ac-420b-9586-cb187849c321  CAS COVID-19 antiviral candidate compounds dat...
# ab59bcdd-7b7c-4107-93f5-0ccaf749236c  CAS COVID-19 antiviral candidate compounds dat...
# fd23e7e0-a5d2-4f98-992d-9209c85153bb  CAS COVID-19 antiviral candidate compounds dat...
#
#                                                                           cleaned_label
# Id
# d0fa7568-7d8e-4db9-870f-f9c6f668c17b              national education longitudinal study
# 2f26f645-3dec-485d-b68d-f013c9e05e60              national education longitudinal study
# c5d5cd2c-59de-4f29-bbb1-6a88c7b52f29              national education longitudinal study
# 5c9a3bc9-41ba-4574-ad71-e25c1442c8af              national education longitudinal study
# c754dec7-c5a3-4337-9892-c02158475064              national education longitudinal study
# ...                                                                                 ...
# f89dd9fa-07af-4384-aa0c-0d14602c0cea  rsna international covid 19 open radiology dat...
# b3498176-8832-4033-aea6-b5ea85ea04c4   rsna international covid open radiology database
# f77eb51f-c3ac-420b-9586-cb187849c321  cas covid 19 antiviral candidate compounds dat...
# ab59bcdd-7b7c-4107-93f5-0ccaf749236c  cas covid 19 antiviral candidate compounds dat...
# fd23e7e0-a5d2-4f98-992d-9209c85153bb  cas covid 19 antiviral candidate compounds dat...
#
# [14316 rows x 4 columns]

# %%
dataset.loc["d0fa7568-7d8e-4db9-870f-f9c6f668c17b", "cleaned_label"]
# Out:
# 'national education longitudinal study'

# %% [markdown]
# ### Associa aos IDs em dataset o texto contido no arquivo .json correspondente

# %%
for ID, text in id2text.items():
    dataset.loc[ID, "text"] = text

dataset
# Out:
#                                                                               pub_title  \
# Id
# d0fa7568-7d8e-4db9-870f-f9c6f668c17b  The Impact of Dual Enrollment on College Degre...
# 2f26f645-3dec-485d-b68d-f013c9e05e60  Educational Attainment of High School Dropouts...
# c5d5cd2c-59de-4f29-bbb1-6a88c7b52f29  Differences in Outcomes for Female and Male St...
# 5c9a3bc9-41ba-4574-ad71-e25c1442c8af  Stepping Stone and Option Value in a Model of ...
# c754dec7-c5a3-4337-9892-c02158475064  Parental Effort, School Resources, and Student...
# ...                                                                                 ...
# f89dd9fa-07af-4384-aa0c-0d14602c0cea  Artificial Intelligence of COVID-19 Imaging: A...
# b3498176-8832-4033-aea6-b5ea85ea04c4  RSNA International Trends: A Global Perspectiv...
# f77eb51f-c3ac-420b-9586-cb187849c321  MCCS: a novel recognition pattern-based method...
# ab59bcdd-7b7c-4107-93f5-0ccaf749236c  Quantitative Structure–Activity Relationship M...
# fd23e7e0-a5d2-4f98-992d-9209c85153bb  A ligand-based computational drug repurposing ...
#
#                                                                           dataset_title  \
# Id
# d0fa7568-7d8e-4db9-870f-f9c6f668c17b              National Education Longitudinal Study
# 2f26f645-3dec-485d-b68d-f013c9e05e60              National Education Longitudinal Study
# c5d5cd2c-59de-4f29-bbb1-6a88c7b52f29              National Education Longitudinal Study
# 5c9a3bc9-41ba-4574-ad71-e25c1442c8af              National Education Longitudinal Study
# c754dec7-c5a3-4337-9892-c02158475064              National Education Longitudinal Study
# ...                                                                                 ...
# f89dd9fa-07af-4384-aa0c-0d14602c0cea  RSNA International COVID-19 Open Radiology Dat...
# b3498176-8832-4033-aea6-b5ea85ea04c4  RSNA International COVID-19 Open Radiology Dat...
# f77eb51f-c3ac-420b-9586-cb187849c321  CAS COVID-19 antiviral candidate compounds dat...
# ab59bcdd-7b7c-4107-93f5-0ccaf749236c  CAS COVID-19 antiviral candidate compounds dat...
# fd23e7e0-a5d2-4f98-992d-9209c85153bb  CAS COVID-19 antiviral candidate compounds dat...
#
#                                                                           dataset_label  \
# Id
# d0fa7568-7d8e-4db9-870f-f9c6f668c17b              National Education Longitudinal Study
# 2f26f645-3dec-485d-b68d-f013c9e05e60              National Education Longitudinal Study
# c5d5cd2c-59de-4f29-bbb1-6a88c7b52f29              National Education Longitudinal Study
# 5c9a3bc9-41ba-4574-ad71-e25c1442c8af              National Education Longitudinal Study
# c754dec7-c5a3-4337-9892-c02158475064              National Education Longitudinal Study
# ...                                                                                 ...
# f89dd9fa-07af-4384-aa0c-0d14602c0cea  RSNA International COVID-19 Open Radiology Dat...
# b3498176-8832-4033-aea6-b5ea85ea04c4   RSNA International COVID Open Radiology Database
# f77eb51f-c3ac-420b-9586-cb187849c321  CAS COVID-19 antiviral candidate compounds dat...
# ab59bcdd-7b7c-4107-93f5-0ccaf749236c  CAS COVID-19 antiviral candidate compounds dat...
# fd23e7e0-a5d2-4f98-992d-9209c85153bb  CAS COVID-19 antiviral candidate compounds dat...
#
#                                                                           cleaned_label  \
# Id
# d0fa7568-7d8e-4db9-870f-f9c6f668c17b              national education longitudinal study
# 2f26f645-3dec-485d-b68d-f013c9e05e60              national education longitudinal study
# c5d5cd2c-59de-4f29-bbb1-6a88c7b52f29              national education longitudinal study
# 5c9a3bc9-41ba-4574-ad71-e25c1442c8af              national education longitudinal study
# c754dec7-c5a3-4337-9892-c02158475064              national education longitudinal study
# ...                                                                                 ...
# f89dd9fa-07af-4384-aa0c-0d14602c0cea  rsna international covid 19 open radiology dat...
# b3498176-8832-4033-aea6-b5ea85ea04c4   rsna international covid open radiology database
# f77eb51f-c3ac-420b-9586-cb187849c321  cas covid 19 antiviral candidate compounds dat...
# ab59bcdd-7b7c-4107-93f5-0ccaf749236c  cas covid 19 antiviral candidate compounds dat...
# fd23e7e0-a5d2-4f98-992d-9209c85153bb  cas covid 19 antiviral candidate compounds dat...
#
#                                                                                    text
# Id
# d0fa7568-7d8e-4db9-870f-f9c6f668c17b  [{"section_title": "What is this study about?"...
# 2f26f645-3dec-485d-b68d-f013c9e05e60  [{"section_title": "November 2004", "text": "D...
# c5d5cd2c-59de-4f29-bbb1-6a88c7b52f29  [{"section_title": "Differences in Outcomes fo...
# 5c9a3bc9-41ba-4574-ad71-e25c1442c8af  [{"section_title": "Abstract", "text": "Federa...
# c754dec7-c5a3-4337-9892-c02158475064  [{"section_title": "Abstract", "text": "This a...
# ...                                                                                 ...
# f89dd9fa-07af-4384-aa0c-0d14602c0cea  [{"section_title": "", "text": "T he coronavir...
# b3498176-8832-4033-aea6-b5ea85ea04c4  [{"section_title": "Introduction", "text": "Ou...
# f77eb51f-c3ac-420b-9586-cb187849c321  [{"section_title": "Introduction", "text": "Th...
# ab59bcdd-7b7c-4107-93f5-0ccaf749236c  [{"section_title": "INTRODUCTION", "text": "Th...
# fd23e7e0-a5d2-4f98-992d-9209c85153bb  [{"section_title": "", "text": "deployment of ...
#
# [14316 rows x 5 columns]

# %% [markdown]
# # 3) Armazenamento do dataset limpo
#
# ### Salva o dataset em um arquivo serializado (pickle) para não precisar rodar get_JSON() de novo

# %%
dataset.to_pickle('clean_train')
